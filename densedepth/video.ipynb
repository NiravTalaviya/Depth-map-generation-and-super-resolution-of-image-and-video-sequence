# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Kitti Dataset Downloader

# %%
# !rm -rf 2011_09_26

# %%
os.chdir('/content/')

# %%
# %%shell
# #!/bin/bash
#
# files=(2011_09_26_calib.zip
# 2011_09_26_drive_0001
# 2011_09_26_drive_0002
# 2011_09_26_drive_0005
# 2011_09_26_drive_0009
# 2011_09_26_drive_0011
# 2011_09_26_drive_0013
# 2011_09_26_drive_0014
# 2011_09_26_drive_0015
# 2011_09_26_drive_0017
# 2011_09_26_drive_0018
# 2011_09_26_drive_0019
# 2011_09_26_drive_0020
# 2011_09_26_drive_0022
# 2011_09_26_drive_0023
# 2011_09_26_drive_0027
# 2011_09_26_drive_0028
# 2011_09_26_drive_0029
# 2011_09_26_drive_0032
# 2011_09_26_drive_0035
# 2011_09_26_drive_0036
# 2011_09_26_drive_0039
# 2011_09_26_drive_0046
# 2011_09_26_drive_0048
# 2011_09_26_drive_0051
# 2011_09_26_drive_0052
# 2011_09_26_drive_0056
# 2011_09_26_drive_0057
# 2011_09_26_drive_0059
# 2011_09_26_drive_0060
# 2011_09_26_drive_0061
# 2011_09_26_drive_0064
# 2011_09_26_drive_0070
# 2011_09_26_drive_0079
# 2011_09_26_drive_0084
# 2011_09_26_drive_0086
# 2011_09_26_drive_0087
# 2011_09_26_drive_0091
# 2011_09_26_drive_0093
# 2011_09_26_drive_0095
# 2011_09_26_drive_0096
# 2011_09_26_drive_0101
# 2011_09_26_drive_0104
# 2011_09_26_drive_0106
# 2011_09_26_drive_0113
# 2011_09_26_drive_0117
# 2011_09_26_drive_0119
# 2011_09_28_calib.zip
# 2011_09_28_drive_0001
# 2011_09_28_drive_0002
# 2011_09_28_drive_0016
# 2011_09_28_drive_0021
# 2011_09_28_drive_0034
# 2011_09_28_drive_0035
# 2011_09_28_drive_0037
# 2011_09_28_drive_0038
# 2011_09_28_drive_0039
# 2011_09_28_drive_0043
# 2011_09_28_drive_0045
# 2011_09_28_drive_0047
# 2011_09_28_drive_0053
# 2011_09_28_drive_0054
# 2011_09_28_drive_0057
# 2011_09_28_drive_0065
# 2011_09_28_drive_0066
# 2011_09_28_drive_0068
# 2011_09_28_drive_0070
# 2011_09_28_drive_0071
# 2011_09_28_drive_0075
# 2011_09_28_drive_0077
# 2011_09_28_drive_0078
# 2011_09_28_drive_0080
# 2011_09_28_drive_0082
# 2011_09_28_drive_0086
# 2011_09_28_drive_0087
# 2011_09_28_drive_0089
# 2011_09_28_drive_0090
# 2011_09_28_drive_0094
# 2011_09_28_drive_0095
# 2011_09_28_drive_0096
# 2011_09_28_drive_0098
# 2011_09_28_drive_0100
# 2011_09_28_drive_0102
# 2011_09_28_drive_0103
# 2011_09_28_drive_0104
# 2011_09_28_drive_0106
# 2011_09_28_drive_0108
# 2011_09_28_drive_0110
# 2011_09_28_drive_0113
# 2011_09_28_drive_0117
# 2011_09_28_drive_0119
# 2011_09_28_drive_0121
# 2011_09_28_drive_0122
# 2011_09_28_drive_0125
# 2011_09_28_drive_0126
# 2011_09_28_drive_0128
# 2011_09_28_drive_0132
# 2011_09_28_drive_0134
# 2011_09_28_drive_0135
# 2011_09_28_drive_0136
# 2011_09_28_drive_0138
# 2011_09_28_drive_0141
# 2011_09_28_drive_0143
# 2011_09_28_drive_0145
# 2011_09_28_drive_0146
# 2011_09_28_drive_0149
# 2011_09_28_drive_0153
# 2011_09_28_drive_0154
# 2011_09_28_drive_0155
# 2011_09_28_drive_0156
# 2011_09_28_drive_0160
# 2011_09_28_drive_0161
# 2011_09_28_drive_0162
# 2011_09_28_drive_0165
# 2011_09_28_drive_0166
# 2011_09_28_drive_0167
# 2011_09_28_drive_0168
# 2011_09_28_drive_0171
# 2011_09_28_drive_0174
# 2011_09_28_drive_0177
# 2011_09_28_drive_0179
# 2011_09_28_drive_0183
# 2011_09_28_drive_0184
# 2011_09_28_drive_0185
# 2011_09_28_drive_0186
# 2011_09_28_drive_0187
# 2011_09_28_drive_0191
# 2011_09_28_drive_0192
# 2011_09_28_drive_0195
# 2011_09_28_drive_0198
# 2011_09_28_drive_0199
# 2011_09_28_drive_0201
# 2011_09_28_drive_0204
# 2011_09_28_drive_0205
# 2011_09_28_drive_0208
# 2011_09_28_drive_0209
# 2011_09_28_drive_0214
# 2011_09_28_drive_0216
# 2011_09_28_drive_0220
# 2011_09_28_drive_0222
# 2011_09_28_drive_0225
# 2011_09_29_calib.zip
# 2011_09_29_drive_0004
# 2011_09_29_drive_0026
# 2011_09_29_drive_0071
# 2011_09_29_drive_0108
# 2011_09_30_calib.zip
# 2011_09_30_drive_0016
# 2011_09_30_drive_0018
# 2011_09_30_drive_0020
# 2011_09_30_drive_0027
# 2011_09_30_drive_0028
# 2011_09_30_drive_0033
# 2011_09_30_drive_0034
# 2011_09_30_drive_0072
# 2011_10_03_calib.zip
# 2011_10_03_drive_0027
# 2011_10_03_drive_0034
# 2011_10_03_drive_0042
# 2011_10_03_drive_0047
# 2011_10_03_drive_0058)
#
# for i in ${files[@]}; do
#         if [ ${i:(-3)} != "zip" ]
#         then
#                 shortname=$i'_sync.zip'
#                 fullname=$i'/'$i'_sync.zip'
#         else
#                 shortname=$i
#                 fullname=$i
#         fi
# 	echo "Downloading: "$shortname
#         wget 'https://s3.eu-central-1.amazonaws.com/avg-kitti/raw_data/'$fullname
#         unzip -o $shortname
#         rm $shortname
# done
# Out:
# Downloading: 2011_09_26_calib.zip
# --2020-04-20 09:01:34--  https://s3.eu-central-1.amazonaws.com/avg-kitti/raw_data/2011_09_26_calib.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.74.171
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.74.171|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4068 (4.0K) [application/zip]
# Saving to: ‘2011_09_26_calib.zip’
#
# 2011_09_26_calib.zi 100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2020-04-20 09:01:35 (141 MB/s) - ‘2011_09_26_calib.zip’ saved [4068/4068]
#
# Archive:  2011_09_26_calib.zip
#  extracting: 2011_09_26/calib_cam_to_cam.txt
#  extracting: 2011_09_26/calib_imu_to_velo.txt
#  extracting: 2011_09_26/calib_velo_to_cam.txt
# Downloading: 2011_09_26_drive_0001_sync.zip
# --2020-04-20 09:01:35--  https://s3.eu-central-1.amazonaws.com/avg-kitti/raw_data/2011_09_26_drive_0001/2011_09_26_drive_0001_sync.zip
# ...

# %% [markdown]
# # Define Model

# %%
try:
    # %tensorflow_version 2.x
except:
    pass
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %% [markdown]
# ## Upscale block

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, UpSampling2D, LeakyReLU, Concatenate
from tensorflow.keras.applications import DenseNet169

class UpscaleBlock(Model):
    def __init__(self, filters):
        # call parent constructor
        super(UpscaleBlock, self).__init__()
        ALPHA = 0.2

        self.upscl = UpSampling2D(interpolation='bilinear', )
        self.cncat = Concatenate()

        self.convA = Conv2D(filters, (3, 3) , padding='same')
        self.reluA = LeakyReLU(alpha=ALPHA)  

        self.convB = Conv2D(filters, (3, 3), padding='same')
        self.reluB = LeakyReLU(alpha=ALPHA)
    
    def call(self, inputs):
        x = self.upscl(inputs[0])
        x = self.cncat([x, inputs[1]])
        
        x = self.convA(x)
        x = self.reluA(x)

        x = self.convB(x)
        x = self.reluB(x)

        return x

# %% [markdown]
# ## Encode Block

# %%
class Encoder(Model):
    def __init__(self):
        super(Encoder, self).__init__()

        self.base = DenseNet169(input_shape=(None, None, 3) ,include_top=False)

        outputs = [self.base.outputs[-1]]
        for name in ['pool1', 'pool2_pool', 'pool3_pool', 'conv1/relu']:
            outputs.append(self.base.get_layer(name).output)

        self.encoder = Model(inputs = self.base.inputs, outputs = outputs)       

    def call(self, inputs):
        x = self.encoder(inputs)
        return x

# %%
class Decoder(Model):
    def __init__(self, filters):
        super(Decoder, self).__init__()

        self.convA = Conv2D(filters, (1, 1), padding='same')

        self.upA = UpscaleBlock(filters=filters//2)
        self.upB = UpscaleBlock(filters=filters//4)
        self.upC = UpscaleBlock(filters=filters//8)
        self.upD = UpscaleBlock(filters=filters//16)

        self.convB = Conv2D(1, (3, 3), padding='same')
    
    def call(self, inputs):
        x, pool1, pool2, pool3, conv1 = inputs[0], inputs[1], inputs[2], inputs[3], inputs[4]

        x = self.convA(x)
        x = self.upA([x, pool3])
        x = self.upB([x, pool2])
        x = self.upC([x, pool1])
        x = self.upD([x, conv1])
        x = self.convB(x)

        return x

# %%
class DenseDepth(Model):
    def __init__(self):
        super(DenseDepth, self).__init__()
        
        self.encoder = Encoder()
        self.decoder = Decoder(filters=int(self.encoder.layers[-1].output[0].shape[-1] // 2))
    
    def call(self, inputs):
        x = self.encoder(inputs)
        x = self.decoder(x)

        return x

import cv2
import numpy as np
def DepthNorm(x, maxDepth):
    return maxDepth / x

def predict(model, images, minDepth=10, maxDepth=1000, batch_size=2):
    # Support multiple RGBs, one RGB image, even grayscale 
    if len(images.shape) < 3: images = np.stack((images,images,images), axis=2)
    if len(images.shape) < 4: images = images.reshape((1, images.shape[0], images.shape[1], images.shape[2]))
    # Compute predictions
    predictions = model.predict(images, batch_size=batch_size)
    # Put in expected range
    return np.clip(DepthNorm(predictions, maxDepth=maxDepth), minDepth, maxDepth) / maxDepth

# %%
DEPTH_MODEL_PATH = '/content/drive/My Drive/project/super-resolution/video/training/'

# %%
print('Loading model...')
model = DenseDepth()
checkpoint_path = DEPTH_MODEL_PATH + "DenseDepth.ckpt"
model.load_weights(checkpoint_path)
print('Model weights loaded.')
# Out:
# Loading model...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).decoder.convA.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).decoder.convA.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).decoder.convB.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).decoder.convB.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).decoder.upA.convA.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).decoder.upA.convA.bias
# ...

# %% [markdown]
# # SR model

# %%
from tensorflow.keras import backend as K
def PSNR(y_true, y_pred):
    max_val = 1.0
    return tf.image.psnr(y_true, y_pred, max_val=max_val)

dependency = {
    'PSNR': PSNR
}

from tensorflow.keras import layers
import os
import math
import numpy as np
def predict_model():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(128, (9, 9), input_shape=(None, None, 1), padding='valid'))
    model.add(layers.LeakyReLU())
    model.add(layers.Conv2D(64, (3,3), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Conv2D(1, (5, 5), activation='linear', padding='valid'))
    adam = tf.keras.optimizers.Adam(3e-4)

    model.compile(optimizer=adam,
                  loss='mse',
                  metrics=['mean_squared_error', PSNR])
    
    return model

# %%
predict_srcnn = predict_model()
predict_srcnn.summary()
weights_file = '/content/drive/My Drive/project/super-resolution/video/SRCNN_checkpoint.h5'
predict_srcnn.load_weights(weights_file)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_20 (Conv2D)           (None, None, None, 128)   10496
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, None, None, 128)   0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, None, None, 64)    73792
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, None, None, 64)    0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, None, None, 1)     1601
# ...
# Total params: 85,889
# Trainable params: 85,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
SAVE_PATH = '/content/'
DATA_PATH = '/content/2011_09_26/2011_09_26_drive_0015_sync/image_01/data/'
#DATA_PATH = '/content/drive/My Drive/project/super-resolution/data/square/'
DATA_PATH = '/content/example/'

# %%
files = os.listdir(DATA_PATH)
files.sort()
# model.summary()

# %% [markdown]
# # Evaluation
# Make sure image size if divisible by 32

# %% [markdown]
# ## SR

# %%
def super_resolve(model, img, sr_factor=2, CONVOLUTION_SIZE=6):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)
    shape = img.shape
    img = cv2.resize(img, (shape[1]*sr_factor, shape[0]*sr_factor), cv2.INTER_CUBIC)
    Y_img = img[:,:,0]

    Y = np.zeros((1, img.shape[0], img.shape[1], 1), dtype=float)
    Y[0, :, :, 0] = Y_img.astype(float) / 255.
    pre = model.predict(Y, batch_size=1) * 255.
    pre[pre[:] > 255] = 255
    pre[pre[:] < 0] = 0
    pre = pre.astype(np.uint8)
    
    if CONVOLUTION_SIZE != 0:
        img[CONVOLUTION_SIZE: -CONVOLUTION_SIZE, CONVOLUTION_SIZE: -CONVOLUTION_SIZE, 0] = pre[0, :, :, 0]
    else:
        img[0:,0:,0] = pre[0, :, :, 0]

    
    img = cv2.cvtColor(img, cv2.COLOR_YCrCb2BGR)
    return img

# %%
## TEST SR
count = 5
(fig, axes) = plt.subplots(nrows=count, ncols=2, figsize=(15,15))
i = 0
path_pre = DATA_PATH
for f in files:
    depth_file = f
    img = cv2.imread(path_pre + f, cv2.IMREAD_COLOR)
    #img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    axes[i][0].imshow(img)
    axes[i][0].set_title('OG')

    #img = np.clip(img/255, 0, 1)
    print(img.shape)
    img = super_resolve(predict_srcnn, img)
    print(img.shape)
    axes[i][1].imshow(img)
    axes[i][1].set_title('SR')
    
    if i == count-1:
        break
    else:
        i += 1
#plt.savefig('/content/result.png')
# Out:
# (480, 640, 3)
# (960, 1280, 3)
# (480, 640, 3)
# (960, 1280, 3)
# (480, 640, 3)
# (960, 1280, 3)
# (480, 640, 3)
# (960, 1280, 3)
# (480, 640, 3)
# (960, 1280, 3)

# %% [markdown]
# # DEPTH

# %%
count = 5
(fig, axes) = plt.subplots(nrows=count, ncols=5, figsize=(15,15))
i = 0
path_pre = DATA_PATH
for f in files:
    depth_file = f
    lr_img = cv2.imread(path_pre + f, cv2.IMREAD_COLOR)

    ## SUPER RESOLVE
    img = super_resolve(predict_srcnn, lr_img)

    #img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    h = int(img.shape[0] / 32) * 32
    w = int(img.shape[1] / 32) * 32
    img = img[0:h, 0:w, :]
    print(img.shape)
    axes[i][0].imshow(lr_img)
    axes[i][0].set_title('OG')

    axes[i][1].imshow(img)
    axes[i][1].set_title('SR image')

    img = np.clip(img/255, 0, 1)
    img = predict(model, img, batch_size=1)
    axes[i][2].imshow(img[0,:,:,0], cmap='plasma')
    axes[i][2].set_title('SR then depth')

    lr_img = np.clip(lr_img/255, 0, 1)
    lr_img = predict(model, lr_img, batch_size=1)
    axes[i][3].imshow(lr_img[0,:,:,0], cmap='plasma')
    axes[i][3].set_title('OG Depth')

    img = cv2.resize(lr_img[0,:,:,0], (lr_img.shape[2]*2, lr_img.shape[1]*2), cv2.INTER_CUBIC)
    print(img.shape)
    Y = np.zeros((1, img.shape[0], img.shape[1], 1), dtype=float)
    Y[0, :, :, 0] = img.astype(float)
    pre = predict_srcnn.predict(Y, batch_size=1)
    
    CONVOLUTION_SIZE = 6
    if CONVOLUTION_SIZE != 0:
        img[CONVOLUTION_SIZE: -CONVOLUTION_SIZE, CONVOLUTION_SIZE: -CONVOLUTION_SIZE] = pre[0, :, :, 0]
    else:
        img = pre[0, :, :, 0]

    axes[i][4].imshow(img, cmap='plasma')
    axes[i][4].set_title('depth then SR')

    if i == count-1:
        break
    else:
        i += 1
    
plt.savefig('/content/result.png')
# Out:
# (960, 1280, 3)
# (480, 640)
# (960, 1280, 3)
# (480, 640)
# (960, 1280, 3)
# (480, 640)
# (960, 1280, 3)
# (480, 640)
# (960, 1280, 3)
# (480, 640)

# %% [markdown]
# # Read Video

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
# print('Loading model...')
# model = DenseDepth()
# checkpoint_path = DEPTH_MODEL_PATH + "DenseDepth.ckpt"
# model.load_weights(checkpoint_path)
# print('Model weights loaded.')

cap = cv2.VideoCapture('/content/drive/My Drive/project/super-resolution/data/realworld/indoor_2.mp4')
if (cap.isOpened()== False): 
    print("Error opening video stream or file")

w = int(cap.get(3))
h = int(cap.get(4))
flag=0
frame_array=[]
size = (w,h)
while cap.isOpened():
    ret, img = cap.read()
    if ret == True:
        global tem
        tem = img
        h = int(tem.shape[0] / 32) * 32
        w = int(tem.shape[1] / 32) * 32
        tem = tem[0:h, 0:w, :]
        tem = np.clip(tem/255, 0, 1)
        tem = predict(model, tem, batch_size=1)
        flag = flag + 1
        plt.imsave('temp.jpg', tem[0,:,:,0], cmap='plasma')
        img = plt.imread('temp.jpg')
        h = img.shape[0]
        w = img.shape[1]
        size = (w, h)
        # plt.figure()
        # plt.imshow(img)
        # plt.show()
        print(img.shape)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        frame_array.append(img)
        print('Frame '+str(flag))
    else:
        break

# Creating Output Video

pathOut='t1.avi';
fps = 30
size = (frame_array[0].shape[1], frame_array[0].shape[0])

out = cv2.VideoWriter(pathOut, cv2.VideoWriter_fourcc(*'DIVX'), fps, size)

for i in range(len(frame_array)):
    print('Frame '+str(i)+' appended')
    out.write(frame_array[i])
out.release()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
# print('Loading model...')
# model = DenseDepth()
# checkpoint_path = DEPTH_MODEL_PATH + "DenseDepth.ckpt"
# model.load_weights(checkpoint_path)
# print('Model weights loaded.')
input_path = '/content/drive/My Drive/project/super-resolution/data/realworld/indoor_2.mp4'
pre = input_path[:-4] 
pathOut=pre+'_output'+input_path[len(pre):]

cap = cv2.VideoCapture(input_path)

if (cap.isOpened()== False): 
    print("Error opening video stream or file")

w = int(cap.get(3))
h = int(cap.get(4))
flag=0
frame_array=[]
size = (w,h)
while cap.isOpened():
    ret, img = cap.read()
    if ret == True:
        global tem
        tem = img        
        original = tem
        h = int(tem.shape[0] / 32) * 32
        w = int(tem.shape[1] / 32) * 32
        tem = tem[0:h, 0:w, :]
        tem = np.clip(tem/255, 0, 1)
        tem = predict(model, tem, batch_size=1)
        flag = flag + 1
        plt.imsave('temp.jpg', tem[0,:,:,0], cmap='plasma')
        img = plt.imread('temp.jpg')
        h = img.shape[0]
        w = img.shape[1]
        size = (w, h)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        out = img
        # Comment next ##__## line for not letting combining original and output image
        ##
        out = np.uint8(np.zeros((img.shape[0],2*img.shape[1],3)))
        out[:img.shape[0],:img.shape[1],:] = img
        out[:img.shape[0],y_offset:y_offset+img.shape[1],:] = cv2.resize(original, dsize=(img.shape[1], img.shape[0]))
        ##
        frame_array.append(out)
        print('Frame '+str(flag))
    else:
        break

# Creating Output Video

fps = 30
size = (frame_array[0].shape[1], frame_array[0].shape[0])

out = cv2.VideoWriter(pathOut, cv2.VideoWriter_fourcc(*'DIVX'), fps, size)

for i in range(len(frame_array)):
    print('Frame '+str(i)+' appended')
    out.write(frame_array[i])
out.release()        
print('Output saved at '+pathOut)
# Out:
# Frame 1
# Frame 2
# Frame 3
# Frame 4
# Frame 5
# Frame 6
# Frame 7
# Frame 8
# Frame 9
# Frame 10
# Frame 11
# Frame 12
# Frame 13
# Frame 14
# Frame 15
# Frame 16
# Frame 17
# Frame 18
# Frame 19
# Frame 20
# Frame 21
# Frame 22
# Frame 23
# Frame 24
# Frame 25
# Frame 26
# Frame 27
# Frame 28
# Frame 29
# Frame 30
# Frame 31
# Frame 32
# Frame 33
# Frame 34
# Frame 35
# Frame 36
# Frame 37
# Frame 38
# Frame 39
# Frame 40
# Frame 41
# Frame 42
# Frame 43
# Frame 44
# Frame 45
# Frame 46
# Frame 47
# Frame 48
# Frame 49
# Frame 50
# Frame 51
# Frame 52
# Frame 53
# Frame 54
# Frame 55
# Frame 56
# Frame 57
# Frame 58
# Frame 59
# Frame 60
# Frame 61
# Frame 62
# Frame 63
# Frame 64
# Frame 65
# Frame 66
# Frame 67
# Frame 68
# Frame 69
# Frame 70
# Frame 71
# Frame 72
# Frame 73
# Frame 74
# Frame 75
# Frame 76
# Frame 77
# Frame 78
# Frame 79
# Frame 80
# Frame 81
# Frame 82
# Frame 83
# Frame 84
# Frame 85
# Frame 86
# Frame 87
# Frame 88
# Frame 89
# Frame 90
# Frame 91
# ...

# %%
# a = np.zeros((5,7,3))
b = np.zeros((5,7,3))
c = np.concatenate((a,b),axis=1)
print(c.shape)
# Out:
# (5, 14, 3)

# %%
# !pwd
# Out:
# /content

# %%
import cv2, numpy as np
writer = cv2.VideoWriter("rand3.avi",
cv2.VideoWriter_fourcc(*"MJPG"), 10,(640,480))

for frame in range(100):
    writer.write(np.random.randint(0, 255, (480,640,3)).astype('uint8'))

writer.release()

# %%
model.summary()
# Out:
# Model: "dense_depth"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# encoder (Encoder)            multiple                  12642880
# _________________________________________________________________
# decoder (Decoder)            multiple                  1385280
# ...
# Total params: 14,028,160
# Trainable params: 13,869,760
# Non-trainable params: 158,400
# _________________________________________________________________
